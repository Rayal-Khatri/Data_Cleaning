# %% [markdown]
# # Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Dataset

# %%
# Load dataset
dataset_path = r"https://drive.google.com/uc?export=download&id=1EYv3V2koljcYcDpsqZi7QFsmjmOwBRtI"
df = pd.read_csv(dataset_path)
df.shape
# Out:
# (1460, 81)

# %%
df.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 2         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 3         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 4         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
df.head(6)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# ...

# %%
missing_val= df.isnull().sum()/df.shape[0] *100
missing_val
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType       59.726027
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# ...

# %%
remove_val = missing_val[missing_val>20].keys()
remove_val
# Out:
# Index(['Alley', 'MasVnrType', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
df2 = df.drop(columns = remove_val)
df2.shape
# Out:
# (1460, 75)

# %%
df2 = df2.select_dtypes(include=['int64', 'float64'])
df2.head(4)
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          2003       196.0         706           0        150          856
# 1          1976         0.0         978           0        284         1262
# 2          2002       162.0         486           0        434          920
# 3          1970         0.0         216           0        540          756
#
#    1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0       856       854             0       1710             1             0
# ...

# %%
df2.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
# List of columns with missing values
columns_with_null = [var for var in df2.columns if df2[var].isnull().sum() > 0]
columns_with_null
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
plt.figure(figsize=(15,15))
sns.set()

for i, var in enumerate(columns_with_null):
    plt.subplot(2,2,i+1)
    sns.histplot(
        df2[var],
        bins = 20,
        kde= True,
        # color='#DC143C',
        line_kws={'linewidth': 5},
    )

# %% [markdown]
# ## When the graph is bell shaped and is symmetric about y-axis, Take Mean, Median and Mode
#
# ## Use Median when asymmetric. Refer to image inside the dataset folder for visualization
#
# #Use mean median when the missing values are random

# %%
df3 = df2.fillna(df2.mean())
df3.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(16,16))
sns.set()

for i,var in enumerate(columns_with_null):
    plt.subplot(2,2,i+1)
    sns.histplot(
        df2[var]+5,
        bins= 20,
        kde=True,
        line_kws={'linewidth': 5},
        label = 'Orginal',
    )
    sns.histplot(
        df3[var],
        bins= 20,
        kde=True,
        line_kws={'linewidth': 5,'color' :'green'},
        label = 'Cleaned',
        alpha = .4
    )
    plt.legend()

# %%
df4 = df2.fillna(df2.median())
df4.isnull().sum().sum()
# Out:
# 0

# %%
plt.figure(figsize=(16,16))
sns.set()

for i,var in enumerate(columns_with_null):
    plt.subplot(2,2,i+1)
    sns.distplot(
        df2[var]+5,
        bins= 20,
        kde=True,
        kde_kws={'linewidth': 5},
        label = 'Orginal',
        hist = False,
    )
    sns.distplot(
        df3[var]+5,
        bins= 20,
        kde=True,
        kde_kws={'linewidth': 5},
        label = 'Mean',
        hist = False,
    )
    sns.distplot(
        df4[var],
        bins= 20,
        kde=True,
        kde_kws={'linewidth': 5,'color' :'green'},
        label = 'Median',
        hist = False,
    )
    plt.legend()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_4468\3264568399.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# C:\Users\user\AppData\Local\Temp\ipykernel_4468\3264568399.py:14: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(
# ...

# %% [markdown]
# # To get outliers

# %%
for i,var in enumerate(columns_with_null):
    plt.figure(figsize=(10,10))
    plt.subplot(3,1,1)
    sns.boxplot(x=df2[var])
    plt.subplot(3,1,2)
    sns.boxplot(x=df3[var])
    plt.subplot(3,1,3)
    sns.boxplot(x=df3[var])

    plt.tight_layout() 
    plt.show()
